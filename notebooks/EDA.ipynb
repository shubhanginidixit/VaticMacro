# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load dataset for EDA
df = pd.read_csv("../data/inflation_dataset.csv")
df['Date'] = pd.to_datetime(df['Date'])

# %%
plt.figure(figsize=(12, 10))
correlation_matrix = df.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, fmt='.2f', 
            square=True, linewidths=1, cbar_kws={"shrink": 0.8})
plt.title("Correlation Heatmap - All Variables", fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig("../visualizations/correlation_heatmap.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Correlation Analysis
# Display correlations between all numeric variables in the dataset to identify relationships with inflation.

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['INDCPIALLMINMEI'], linewidth=2, color='#2E86AB')
plt.title("Inflation Trend (CPI)", fontsize=14, fontweight='bold')
plt.xlabel("Date", fontsize=12)
plt.ylabel("CPI Index", fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig("../visualizations/inflation_trends.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## CPI Trend Analysis
# Visualize the inflation trend using the Consumer Price Index (INDCPIALLMINMEI) over time.

# %%
df = pd.read_csv("../data/inflation_dataset.csv")
df['Date'] = pd.to_datetime(df['Date'])
print(f"Dataset shape: {df.shape}")
print(f"Date range: {df['Date'].min()} to {df['Date'].max()}")
# Out:
# Dataset shape: (7023, 10)
# Date range: 2000-01-01 00:00:00 to 2026-05-15 00:00:00

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# This notebook performs exploratory analysis on the inflation dataset, including trend visualization and correlation analysis.
